# %% [markdown]
# # Wrangling Data
#
# ### Author: Avikal Somvanshi

# %%
from __future__ import print_function, division
import pandas as pd
import pylab as pl
import os
import csv
from pandas.tools.plotting import scatter_matrix
import sys
reload(sys)
import zipfile
sys.setdefaultencoding('utf-8')
# %pylab inline

# %%
#Unzippping downloaded median income data of 1999 in a dataframe
zipfile.ZipFile(os.path.join("data/median_hincome_2000.zip")).extractall(r"data/median_hincome_2000")

# %%
#Reading and saving downloaded median income data of 1999 in a dataframe
data_2000 = pd.read_csv('data/median_hincome_2000/DEC_00_SF3_P053_with_ann.csv')
data_2000
# Out:
#                      GEO.id       GEO.id2  \
# 0                        Id           Id2
# 1     1500000US360470001001  360470001001
# 2     1500000US360470001002  360470001002
# 3     1500000US360470001003  360470001003
# 4     1500000US360470002001  360470002001
# 5     1500000US360470002002  360470002002
# 6     1500000US360470003011  360470003011
# 7     1500000US360470003012  360470003012
# 8     1500000US360470003013  360470003013
# 9     1500000US360470003014  360470003014
# 10    1500000US360470003015  360470003015
# 11    1500000US360470003021  360470003021
# 12    1500000US360470005001  360470005001
# 13    1500000US360470005002  360470005002
# 14    1500000US360470005003  360470005003
# 15    1500000US360470005004  360470005004
# 16    1500000US360470005005  360470005005
# 17    1500000US360470007001  360470007001
# 18    1500000US360470007002  360470007002
# 19    1500000US360470007003  360470007003
# 20    1500000US360470009001  360470009001
# ...

# %%
#Unzipping downloaded median income data of 2013 in a dataframe
zipfile.ZipFile(os.path.join("data/median_hincome_2013.zip")).extractall(r"data/median_hincome_2013")

# %%
#Reading and saving downloaded median income data of 2013 in a dataframe
data_2013 = pd.read_csv('data/median_hincome_2013/ACS_13_5YR_B19013_with_ann.csv')
data_2013
# Out:
#                      GEO.id       GEO.id2  \
# 0                        Id           Id2
# 1     1500000US360470001001  360470001001
# 2     1500000US360470001002  360470001002
# 3     1500000US360470001003  360470001003
# 4     1500000US360470001004  360470001004
# 5     1500000US360470002001  360470002001
# 6     1500000US360470003011  360470003011
# 7     1500000US360470003012  360470003012
# 8     1500000US360470003013  360470003013
# 9     1500000US360470003014  360470003014
# 10    1500000US360470003015  360470003015
# 11    1500000US360470005011  360470005011
# 12    1500000US360470005012  360470005012
# 13    1500000US360470005013  360470005013
# 14    1500000US360470005021  360470005021
# 15    1500000US360470005022  360470005022
# 16    1500000US360470007001  360470007001
# 17    1500000US360470007002  360470007002
# 18    1500000US360470007003  360470007003
# 19    1500000US360470009001  360470009001
# 20    1500000US360470009002  360470009002
# ...

# %%
#Merging all the dataframes to a mother dataframe
m_income = pd.merge(data_2000, data_2013, how='outer', on=['GEO.id', 'GEO.id2', 'GEO.display-label'])
m_income
# Out:
#                      GEO.id       GEO.id2  \
# 0                        Id           Id2
# 1     1500000US360470001001  360470001001
# 2     1500000US360470001002  360470001002
# 3     1500000US360470001003  360470001003
# 4     1500000US360470002001  360470002001
# 5     1500000US360470002002  360470002002
# 6     1500000US360470003011  360470003011
# 7     1500000US360470003012  360470003012
# 8     1500000US360470003013  360470003013
# 9     1500000US360470003014  360470003014
# 10    1500000US360470003015  360470003015
# 11    1500000US360470003021  360470003021
# 12    1500000US360470005001  360470005001
# 13    1500000US360470005002  360470005002
# 14    1500000US360470005003  360470005003
# 15    1500000US360470005004  360470005004
# 16    1500000US360470005005  360470005005
# 17    1500000US360470007001  360470007001
# 18    1500000US360470007002  360470007002
# 19    1500000US360470007003  360470007003
# 20    1500000US360470009001  360470009001
# ...

# %%
#Saving the dataset as csv
m_income.to_csv('m_income.csv')

# %%
#Checking the CSV
data = pd.read_csv('m_income.csv')
data.head()
# Out:
#    Unnamed: 0                 GEO.id       GEO.id2  \
# 0           0                     Id           Id2
# 1           1  1500000US360470001001  360470001001
# 2           2  1500000US360470001002  360470001002
# 3           3  1500000US360470001003  360470001003
# 4           4  1500000US360470002001  360470002001
#
#                                    GEO.display-label  \
# 0                                          Geography
# 1  Block Group 1, Census Tract 1, Kings County, N...
# 2  Block Group 2, Census Tract 1, Kings County, N...
# 3  Block Group 3, Census Tract 1, Kings County, N...
# 4  Block Group 1, Census Tract 2, Kings County, N...
#
#                               VD01  \
# 0  Median household income in 1999
# 1                            69821
# 2                            60139
# 3                            57500
# 4                            36750
#
#                                            HD01_VD01  \
# 0  Estimate; Median household income in the past ...
# ...

# %% [markdown]
# ## Good to go!
#
# # Rent Data

# %%
#Unzippping downloaded rent data of 1999 in a dataframe
zipfile.ZipFile(os.path.join("data/median_rent_2000.zip")).extractall(r"data/median_rent_2000")

# %%
#Reading and saving downloaded median income data of 1999 in a dataframe
rdata_2000 = pd.read_csv('data/median_rent_2000/DEC_00_SF3_H063_with_ann.csv')
rdata_2000
# Out:
#                      GEO.id       GEO.id2  \
# 0                        Id           Id2
# 1     1500000US360470001001  360470001001
# 2     1500000US360470001002  360470001002
# 3     1500000US360470001003  360470001003
# 4     1500000US360470002001  360470002001
# 5     1500000US360470002002  360470002002
# 6     1500000US360470003011  360470003011
# 7     1500000US360470003012  360470003012
# 8     1500000US360470003013  360470003013
# 9     1500000US360470003014  360470003014
# 10    1500000US360470003015  360470003015
# 11    1500000US360470003021  360470003021
# 12    1500000US360470005001  360470005001
# 13    1500000US360470005002  360470005002
# 14    1500000US360470005003  360470005003
# 15    1500000US360470005004  360470005004
# 16    1500000US360470005005  360470005005
# 17    1500000US360470007001  360470007001
# 18    1500000US360470007002  360470007002
# 19    1500000US360470007003  360470007003
# 20    1500000US360470009001  360470009001
# ...

# %%
#Unzipping downloaded median income data of 2013 in a dataframe
zipfile.ZipFile(os.path.join("data/median_rent_2013.zip")).extractall(r"data/median_rent_2013")

# %%
#Reading and saving downloaded median income data of 2013 in a dataframe
rdata_2013 = pd.read_csv('data/median_rent_2013/ACS_13_5YR_B25064_with_ann.csv')
rdata_2013
# Out:
#                      GEO.id       GEO.id2  \
# 0                        Id           Id2
# 1     1500000US360470001001  360470001001
# 2     1500000US360470001002  360470001002
# 3     1500000US360470001003  360470001003
# 4     1500000US360470001004  360470001004
# 5     1500000US360470002001  360470002001
# 6     1500000US360470003011  360470003011
# 7     1500000US360470003012  360470003012
# 8     1500000US360470003013  360470003013
# 9     1500000US360470003014  360470003014
# 10    1500000US360470003015  360470003015
# 11    1500000US360470005011  360470005011
# 12    1500000US360470005012  360470005012
# 13    1500000US360470005013  360470005013
# 14    1500000US360470005021  360470005021
# 15    1500000US360470005022  360470005022
# 16    1500000US360470007001  360470007001
# 17    1500000US360470007002  360470007002
# 18    1500000US360470007003  360470007003
# 19    1500000US360470009001  360470009001
# 20    1500000US360470009002  360470009002
# ...

# %%
#Merging all the dataframes to a mother dataframe
m_rent = pd.merge(rdata_2000, rdata_2013, how='outer', on=['GEO.id', 'GEO.id2', 'GEO.display-label'])
m_rent
# Out:
#                      GEO.id       GEO.id2  \
# 0                        Id           Id2
# 1     1500000US360470001001  360470001001
# 2     1500000US360470001002  360470001002
# 3     1500000US360470001003  360470001003
# 4     1500000US360470002001  360470002001
# 5     1500000US360470002002  360470002002
# 6     1500000US360470003011  360470003011
# 7     1500000US360470003012  360470003012
# 8     1500000US360470003013  360470003013
# 9     1500000US360470003014  360470003014
# 10    1500000US360470003015  360470003015
# 11    1500000US360470003021  360470003021
# 12    1500000US360470005001  360470005001
# 13    1500000US360470005002  360470005002
# 14    1500000US360470005003  360470005003
# 15    1500000US360470005004  360470005004
# 16    1500000US360470005005  360470005005
# 17    1500000US360470007001  360470007001
# 18    1500000US360470007002  360470007002
# 19    1500000US360470007003  360470007003
# 20    1500000US360470009001  360470009001
# ...

# %%
#Saving the dataset as csv
m_rent.to_csv('m_rent.csv')

# %%
#Checking the CSV
data = pd.read_csv('m_rent.csv')
data.head()
# Out:
#    Unnamed: 0                 GEO.id       GEO.id2  \
# 0           0                     Id           Id2
# 1           1  1500000US360470001001  360470001001
# 2           2  1500000US360470001002  360470001002
# 3           3  1500000US360470001003  360470001003
# 4           4  1500000US360470002001  360470002001
#
#                                    GEO.display-label               VD01  \
# 0                                          Geography  Median gross rent
# 1  Block Group 1, Census Tract 1, Kings County, N...                750
# 2  Block Group 2, Census Tract 1, Kings County, N...                671
# 3  Block Group 3, Census Tract 1, Kings County, N...                904
# 4  Block Group 1, Census Tract 2, Kings County, N...                835
#
#                      HD01_VD01                           HD02_VD01
# 0  Estimate; Median gross rent  Margin of Error; Median gross rent
# 1                         1867                                1053
# ...

# %% [markdown]
# # Good to go!
